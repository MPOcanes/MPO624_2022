# %% [markdown]
# # Open any OpenDAP link with xarray!

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
testURL = 'https://goldsmr5.gesdisc.eosdis.nasa.gov/dods/M2I3NPASM'
ds = xr.open_dataset(testURL)
ds
# Out:
# /Users/brianmapes/opt/miniconda3/envs/MPO624/lib/python3.8/site-packages/xarray/coding/times.py:144: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# <xarray.Dataset>
# Dimensions:  (time: 122728, lev: 42, lat: 361, lon: 576)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2021-12-31T21:00:00
#   * lev      (lev) float64 1e+03 975.0 950.0 925.0 900.0 ... 0.7 0.5 0.4 0.3 0.1
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables: (12/14)
#     epv      (time, lev, lat, lon) float32 ...
#     h        (time, lev, lat, lon) float32 ...
#     o3       (time, lev, lat, lon) float32 ...
#     omega    (time, lev, lat, lon) float32 ...
#     phis     (time, lat, lon) float32 ...
#     ps       (time, lat, lon) float32 ...
#     ...       ...
#     qv       (time, lev, lat, lon) float32 ...
#     rh       (time, lev, lat, lon) float32 ...
#     slp      (time, lat, lon) float32 ...
#     t        (time, lev, lat, lon) float32 ...
#     u        (time, lev, lat, lon) float32 ...
#     v        (time, lev, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 inst3_3d_asm_Np: 3d,3-Hourly,Instantaneous,Pressure...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Tue Feb 01 21:53:10 GMT 2022 : imported by GrADS Data Serve...

# %%
onetime200 = ds.sel(time='2001-01-01 00:00:00', lev='200')

# %%
onetime200
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 361, lon: 576)
# Coordinates:
#     time     datetime64[ns] 2001-01-01
#     lev      float64 200.0
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables: (12/14)
#     epv      (lat, lon) float32 ...
#     h        (lat, lon) float32 ...
#     o3       (lat, lon) float32 ...
#     omega    (lat, lon) float32 ...
#     phis     (lat, lon) float32 ...
#     ps       (lat, lon) float32 ...
#     ...       ...
#     qv       (lat, lon) float32 ...
#     rh       (lat, lon) float32 ...
#     slp      (lat, lon) float32 ...
#     t        (lat, lon) float32 ...
#     u        (lat, lon) float32 ...
#     v        (lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 inst3_3d_asm_Np: 3d,3-Hourly,Instantaneous,Pressure...
#     Conventions:  COARDS\nGrADS
#     dataType:     Grid
#     history:      Tue Feb 01 21:53:10 GMT 2022 : imported by GrADS Data Serve...

# %%
onetime200.h[0]
# Out:
# <xarray.DataArray 'h' (lon: 576)>
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2001-01-01
#     lev      float64 200.0
#     lat      float64 -90.0
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Attributes:
#     units:      m
#     long_name:  edge heights m
