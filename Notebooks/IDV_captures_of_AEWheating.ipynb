# %% [markdown]
# # Relative importance of surface and moist heating in AEWs

# %%
# %reload_ext ipyidv
# Out:
# ...
# /Users/bem/GitHub/MPO624_2022/Notebooks/idv.xidv

# %%
# %make_movie -capture legend -caption 'Three 12Z snapshots of wind and smoothed vorticity at 850 hPa'

# %%
# %make_movie -capture legend -caption 'With vertical integral moist heating deviations from the 10-day mean'

# %%
# %make_movie -capture legend -caption 'With vertical integral SURFACE heating deviations from the 10-day mean'
